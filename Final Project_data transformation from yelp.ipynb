# %% [markdown]
# # Final Project
#
# Author: Jiaying Wu, Chen Li, Zhao Chen

# %% [markdown]
# ## 1. Dataset Description
# The 3 dataset are from yelp open dataset (in Json file) https://www.yelp.com/dataset/documentation/main
# 1. business.json: Contains business data including location data, attributes, and categories.
# 2. review.json: Contains full review text data including the user_id that wrote the review and the business_id the review is written for.
# 3. user.json: User data including the user's friend mapping and all the metadata associated with the user.

# %%
# Load the Python libraries
import os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Load Surprise libraries
from surprise import SVD
from surprise import Reader
from surprise import Dataset
from surprise import accuracy

# Load plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns

import gc
import re

#map
import folium 

#preprocessing 
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline

# %% [markdown]
# ## 2. Data ETL
# ### 2.1 Business Data
# The objective of this section is to choose restaurants which are open. And we changed the name of the columns to avoid repition in other 2 files. In this part, we deleted attributes and postal code.

# %%
business = pd.read_json('/Users/chenzhaograce/MAS651/Final_Project/yelp_dataset/yelp_academic_dataset_business.json',lines=True)

#finding restaurants restaurants
business['restaurant']= (business.categories.str.contains(pat='Restaurant',
                                                          flags=re.IGNORECASE,
                                                          regex=True))
business.head(5)
# Out:
#               business_id                     name              address  \
# 0  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom         921 Pearl St
# 1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  7000 NE Airport Way
# 2  bvN78flM8NLprQ1a1y5dRg           The Reclaimory   4720 Hawthorne Ave
# 3  oaepsyvc0J17qwi8cfrOWg              Great Clips   2566 Enterprise Rd
# 4  PE9uqAjdw0E4-8mjGl3wVA        Crossfit Terminus  1046 Memorial Dr SE
#
#           city state postal_code   latitude   longitude  stars  review_count  \
# 0      Boulder    CO       80302  40.017544 -105.283348    4.0            86
# 1     Portland    OR       97218  45.588906 -122.593331    4.0           126
# 2     Portland    OR       97214  45.511907 -122.613693    4.5            13
# 3  Orange City    FL       32763  28.914482  -81.295979    3.0             8
# 4      Atlanta    GA       30316  33.747027  -84.353424    4.0            14
#
#    is_open                                         attributes  \
# 0        1  {'RestaurantsTableService': 'True', 'WiFi': 'u...
# 1        1  {'RestaurantsTakeOut': 'True', 'RestaurantsAtt...
# 2        1  {'BusinessAcceptsCreditCards': 'True', 'Restau...
# 3        1  {'RestaurantsPriceRange2': '1', 'BusinessAccep...
# 4        1  {'GoodForKids': 'False', 'BusinessParking': '{...
#
#                                           categories  \
# 0  Gastropubs, Food, Beer Gardens, Restaurants, B...
# 1  Salad, Soup, Sandwiches, Delis, Restaurants, C...
# 2  Antiques, Fashion, Used, Vintage & Consignment...
# 3                         Beauty & Spas, Hair Salons
# 4  Gyms, Active Life, Interval Training Gyms, Fit...
#
#                                                hours restaurant
# 0  {'Monday': '11:0-23:0', 'Tuesday': '11:0-23:0'...       True
# 1  {'Monday': '5:0-18:0', 'Tuesday': '5:0-17:0', ...       True
# 2  {'Thursday': '11:0-18:0', 'Friday': '11:0-18:0...      False
# 3                                               None      False
# 4  {'Monday': '16:0-19:0', 'Tuesday': '16:0-19:0'...      False

# %%
required_columns = ['business_id','name','latitude','longitude','city','state','stars','categories','review_count']  # columns to use 

restaurants = business[(business.restaurant==1)&(business.is_open==1)].reset_index(drop=True)

#keeping required cols 
restaurants=restaurants.loc[:,required_columns]

restaurant_list = restaurants.business_id.unique()   # list of restaurants ids 

print(f'{len(restaurants)} Restaurants(That are Open) in the Dataset')
# Out:
# 32049 Restaurants(That are Open) in the Dataset

# %%
restaurants=restaurants.rename(columns={'stars': 'restaurant_stars','review_count': 'restaurant_review_count'})
restaurants.head(5)
# Out:
#               business_id                     name   latitude   longitude  \
# 0  6iYb2HFDywm3zjuRg0shjw      Oskar Blues Taproom  40.017544 -105.283348
# 1  tCbdrRPZA0oiIYSmHG3J0w  Flying Elephants at PDX  45.588906 -122.593331
# 2  D4JtQNTI4X3KcbzacDJsMw      Bob Likes Thai Food  49.251342 -123.101333
# 3  jFYIsSb7r1QeESVUnXPHBw          Boxwood Biscuit  39.947007  -82.997471
# 4  HPA_qyMEddpAEtFof02ixg      Mr G's Pizza & Subs  42.541155  -70.973438
#
#         city state  restaurant_stars  \
# 0    Boulder    CO               4.0
# 1   Portland    OR               4.0
# 2  Vancouver    BC               3.5
# 3   Columbus    OH               4.5
# 4    Peabody    MA               4.0
#
#                                           categories  restaurant_review_count
# 0  Gastropubs, Food, Beer Gardens, Restaurants, B...                       86
# 1  Salad, Soup, Sandwiches, Delis, Restaurants, C...                      126
# 2                                  Restaurants, Thai                      169
# 3                    Breakfast & Brunch, Restaurants                       11
# 4                           Food, Pizza, Restaurants                       39

# %%
restaurants.to_csv('restaurants.csv',index=False)

# %% [markdown]
# ### 2.2 Review_data
# The objective in this part is to join data with business data. Since the data is really large, we choose the year during Pandemic time (after 2020-01-01). And we select random 10000 data from the dataset.

# %%
#taking these columns for reviews 
required_columns2 = ['review_id','user_id','business_id','text','useful','stars','funny','cool','date']



review_dict = {'id_cols': ['user_id','business_id'],
               'review_cols': ['stars','useful','funny','cool']
              }

# %%
reviews = pd.read_json('/Users/chenzhaograce/MAS651/Final_Project/yelp_dataset/yelp_academic_dataset_review.json',
                      lines=True,
                      orient='columns',
                      chunksize=100000)

# %%
restaurant_reviews = pd.DataFrame()
review_count = 0 
total_reviews =0

# as we are only concerned with restaurants , we will take only those reviews 
for chunk_df in reviews:
    
    total_reviews += chunk_df.shape[0]
    
    #take only those rows which business ids are present in the restaurants df 
    restaurant = chunk_df[chunk_df['business_id'].isin(restaurant_list)].reset_index(drop=True)
    review_count += len(restaurant)    
    
    #append the columns to DF  
    restaurant_reviews=restaurant_reviews.append(restaurant[required_columns2])
    

print(f'There are total {total_reviews} reviews (including restaurant reviews)')
print(f'There are total {review_count} Restaurant reviews in the dataset')
    
assert review_count == restaurant_reviews.shape[0] , 'Hello Darkness my old (only) Friend'
# Out:
# There are total 8635403 reviews (including restaurant reviews)
# There are total 4305580 Restaurant reviews in the dataset

# %%
restaurant_reviews.head(10)
# Out:
#                 review_id                 user_id             business_id  \
# 0  T5fAqjjFooT4V0OeZyuk1w  SFQ1jcnGguO0LYWnbbftAA  0AzLzHfOJgL7ROwhdww2ew
# 1  J4a2TuhDasjn2k3wWtHZnQ  RNm_RWkcd02Li2mKPRe7Eg  xGXzsc-hzam-VArK6eTvtw
# 2  9vqwvFCBG3FBiHGmOHMmiA  XGkAG92TQ3MQUKGX9sLUhw  DbXHNl890xSXNiyRczLWAg
# 3  Gi5LSRmTXoL9Bp4jNGPjLw  hn0ZbitvmlHnF--KJGJ6_A  TA1KUSCu8GkWP9w0rmElxw
# 4  j_eh6Iw7qseluR-7KfZOMg  xpxWG7jQXZE6BcSeuIq4PQ  mw_qxZJraNu7Q6u0GkcMew
# 5  egHMQBhFeaLhVyC6w3r0vQ  HvpNr0ohHCaVLp014CQrdw  gGvNgShksetPoimyKV8I9Q
# 6  ucFOnqgaV40oQ2YNyz5ddQ  JHXQEayrDHOWGexs0dCviA  KXCXaF5qimmtKKqnPc_LQA
# 7  btNWW2kdJYfwpTDyzJO3Iw  DECuRZwkUw8ELQZfNGef2Q  zmZ3HkVCeZPBefJJxzdJ7A
# 8  3c4LFWiVUHPDQzAd8uxc3A  jySmPCkEkJR3cWJlkEs9cw  ZW7aI5FO_3q_vSzI4_zx-Q
# 9  GDgXjXSZCA1iNQWD7OHXfg  1RCRKuHgP3FskGUVnmFdxg  mOnesB4IF9j6-ZmHoOHOig
#
#                                                 text  useful  stars  funny  \
# 0  I've stayed at many Marriott and Renaissance M...       1      2      1
# 1  This place used to be a cool, chill place. Now...       2      1      0
# 2  Probably one of the better breakfast sandwiche...       0      5      0
# 3  I have been here twice and have had really goo...       0      4      0
# 4  This is a five-star restaurant if ever I have ...       0      5      0
# 5  Quickly stopped in for a UFC fight. I sat down...       0      4      0
# 6  Great coffee and pastries. Baristas are excell...       0      1      0
# 7  Nothing special but good enough.  I like anoth...       0      4      0
# 8  Definitely 5 stars for the donuts.  Our family...       5      5      2
# 9  I think their rice dishes are way better than ...       0      4      0
#
#    cool                date
# 0     1 2010-01-08 02:29:15
# 1     0 2018-01-21 04:41:03
# 2     0 2017-12-02 18:16:13
# 3     0 2011-10-27 14:32:57
# 4     0 2016-08-12 21:59:03
# 5     0 2015-10-04 05:37:01
# 6     0 2018-03-03 23:45:25
# 7     0 2012-12-04 04:29:47
# 8     4 2013-08-15 14:47:40
# 9     0 2017-05-26 03:05:46

# %%
restaurant_reviews = restaurant_reviews[(restaurant_reviews.date>='2020-01-01')].reset_index(drop=True)
restaurant_reviews.sort_values('date', ascending=True)
# Out:
#                      review_id                 user_id  \
# 358198  _y-POrlch6GmE3vkhrl_jQ  o1UMvGJYyPlGbrPrMVVPkQ
# 282277  -ehypbwjgP_miIEQTm9zVg  ttMFlp_gAhWsRJt0wUCPbQ
# 134405  VcLqlz8SbrY8p3A1uG1XmA  N1ZCuhN0EFevaIfn6uRTNQ
# 280088  Ex4_j8MREbRhwkSzF_O2CQ  73oJZmR6_MTaQjs1BbjepQ
# 140958  Srm9G-l8x2ECJHVjYiH7Ng  7TVbCA7Oy3y3Jw9h8Skasg
# ...                        ...                     ...
# 194718  d8ugEtIqaDRZTb20kW_t-w  iWcquUJBSE62jR9L278n8A
# 262994  2jTT2ZWVLccVvac6Bhb3ng  Tui3A2NxRTjsbFT92zTMuQ
# 100282  pU-ALbwvmKmLlOVkC-8HsQ  uNSfZyt-xUleywzaPkhk_Q
# 96433   dFL0G1pQlGHA5YR3foto5g  83BBaJTAt-QSA96LFoiUNA
# 306852  u0vJPS9jnLTBFIlLNYerbA  --BMm_Z0PxpsA_XQoqXh2A
#
#                    business_id  \
# 358198  SFqFFIA4Ks2oHfgEANoRlw
# 282277  ogg_C0Nd6CVzUorahN3szA
# 134405  63DvXSks1tHIDajOGvwnRQ
# 280088  4AggS6T6O-ivmuT1L9nGLQ
# 140958  3kUWjyRGWc_RUGDw9X3qUw
# ...                        ...
# 194718  MzPjBeeJGcvwyyRENZU89g
# 262994  _PoE8V45eOpj7zBuB26Nhw
# 100282  9pJAjoekyFksZ6fbpZ7GTw
# 96433   mFbv0sujwZe2YTubuc_Spg
# 306852  QMMECNXYTXzgFgvNy_r-1g
#
#                                                      text  useful  stars  \
# 358198  This restaurant being small plate- it's easy t...       1      5
# 282277  Ordered on NYE, so acknowledge that they may h...       0      1
# 134405  Coffee review only.  They advertise the 'best ...       0      2
# 280088  Relaxing atmosphere, great service and wonderf...       0      4
# 140958  Waited for 40 minutes on two wraps, only for t...       0      1
# ...                                                   ...     ...    ...
# 194718  This spot is amazing. Well worth it for lunch ...       0      5
# 262994  Not much to say... BEST FOOD EVER! My family a...       0      5
# 100282  The best Mediterranean spot in Austin! The foo...       0      5
# 96433   I really love the deep dish pizza here... I su...       0      4
# 306852  I was so full off the delicious and fulfilling...       0      4
#
#         funny  cool                date
# 358198      0     0 2020-01-01 00:00:01
# 282277      0     0 2020-01-01 00:00:10
# 134405      0     0 2020-01-01 00:00:59
# 280088      0     0 2020-01-01 00:03:01
# 140958      0     0 2020-01-01 00:03:04
# ...       ...   ...                 ...
# 194718      0     0 2021-01-28 15:23:52
# 262994      0     0 2021-01-28 15:25:31
# 100282      0     0 2021-01-28 15:30:21
# 96433       0     0 2021-01-28 15:34:59
# 306852      0     0 2021-01-28 15:38:54
#
# [389842 rows x 9 columns]

# %%
#Random 10000 reviews data
restaurant_reviews=restaurant_reviews.sample(n=10000,random_state=1)

# %%
restaurant_review_user_list = restaurant_reviews.user_id.unique()

# %%
#saving restaurant reviews as a csv 
restaurant_reviews.to_csv('restaurant_reviews.csv',
                          index=False)

# %% [markdown]
# ### 2.3. User Information
# In this sections , we will extract the information of users that have written reviews in the restaurant reviews section, and extract some relevant information. And we deleted other unnessary columns.

# %%
required_cols3 = ['user_id','review_count','yelping_since','useful','funny','cool','fans','average_stars','friend_count']

# %%
user_data = pd.read_json('/Users/chenzhaograce/MAS651/Final_Project/yelp_dataset/yelp_academic_dataset_user.json',
                       lines=True,
                       orient='columns',
                       chunksize=100000)


    
user_df = pd.DataFrame()
user_count = 0 
total_users =0

# as we are only concerned with restaurants , we will take only those users with restaurant reviews 
for chunk_df in user_data:    
    
    total_users += chunk_df.shape[0]
    
    #take only those rows which user ids are present in the restaurants review user ids  
    users = chunk_df[chunk_df['user_id'].isin(restaurant_review_user_list)].reset_index(drop=True)
    user_count += len(users)
    
    
    _ = to_datetime(df=users,datetime_column='yelping_since')
    users['yelping_since'] = users['yelping_since'].dt.year
    
    
    #count numof friends user has 
    users['friend_count']  = users['friends'].apply(lambda x: len(x.split(',')))
    #append the rows and columns to DF  
    user_df=user_df.append(users[required_cols3])
    


print(f'There are total {total_users} Users (including users with restaurant reviews)')
print(f'There are total {user_count} Users with Restaurant reviews in the dataset')
    
assert user_count == user_df.shape[0] , 'Knock Knock Whos there? Stupidity you stupid.'
# Out:
# There are total 2189457 Users (including users with restaurant reviews)
# There are total 1364404 Users with Restaurant reviews in the dataset

# %%
user_metadata=user_df.rename(columns={'review_count': 'user_review_count','useful': 'user_useful', 
                                      'funny': 'user_funny', 'cool': 'user_cool','average_stars': 'user_average_stars'})
#user_metadata=user_metadata.iloc[:,:9]

# %%
user_metadata.head(5)
# Out:
#                   user_id  user_review_count  yelping_since  user_useful  \
# 0  q_QQ5kBBwlCcbL1s4NVK3g               1220           2005        15038
# 1  dIIKEfOgo0KqUfGQvGikPg               2136           2007        21272
# 2  D6ErcUnFALnCQN4b1W_TlA                119           2007          188
# 3  JnPIjvC0cmooNDfsa9BmXg                987           2009         7234
# 4  37Hc8hr3cw0iHLoPzLK6Ow                495           2008         1577
#
#    user_funny  user_cool  fans  user_average_stars  friend_count
# 0       10030      11291  1357                3.85          5813
# 1       10289      18046  1025                4.09          6296
# 2         128        130    16                3.76           835
# 3        4722       4035   420                3.77          1452
# 4         727       1124    47                3.72           532

# %%
user_metadata.to_csv('user_metadata.csv',index=False)

# %% [markdown]
# ### 2.4 Merge Data
# We merge 3 dataset together and save the final data to csv file. And we uploaded the file to Github for future use.

# %%
df=restaurant_reviews.merge(user_metadata,on='user_id', how='inner')
yelp=df.merge(restaurants, on='business_id', how='inner')

# %%
yelp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4305580 entries, 0 to 4305579
# Data columns (total 25 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   review_id                object
#  1   user_id                  object
#  2   business_id              object
#  3   text                     object
#  4   useful                   int64
#  5   stars                    int64
#  6   funny                    int64
#  7   cool                     int64
#  8   date                     datetime64[ns]
#  9   user_review_count        int64
#  10  yelping_since            int64
#  11  user_useful              int64
#  12  user_funny               int64
#  13  user_cool                int64
#  14  fans                     int64
#  15  user_average_stars       float64
#  16  friend_count             int64
#  17  name                     object
#  18  latitude                 float64
#  19  longitude                float64
#  20  city                     object
#  21  state                    object
#  22  restaurant_stars         float64
#  23  categories               object
#  24  restaurant_review_count  int64
# dtypes: datetime64[ns](1), float64(4), int64(12), object(8)
# memory usage: 854.1+ MB

# %%
yelp
# Out:
#                       review_id                 user_id  \
# 0        T5fAqjjFooT4V0OeZyuk1w  SFQ1jcnGguO0LYWnbbftAA
# 1        NOl8mfl10jRuX5vH0WnY3Q  dzPFH-A9n98R0_rEaRFkeg
# 2        Qv4o4ov_sevhEuwa3OZA_A  P241NkCS4JR-QxUwpsA9Jg
# 3        xxmUdt1kwgZ21N-RzCMfDg  1hJJXtCULGN8NT2dQtYbMg
# 4        kfuK8FWw88fkQCcEa_H0Hw  zNyqbUCtGZOH6iDv_TsPFw
# ...                         ...                     ...
# 4305575  _2Sp43ly9KXmk0YEjCMbew  PfuwVsIeXBmt8-xLjvwFcA
# 4305576  2n-YNeBVYZleQsDdrJ8nTw  OMwl8un_kLM3HsAhFzBkMQ
# 4305577  A7mjoQD_YgFtSvKuawUSMw  NY0f24S6Ca3ZZMK2y8YLWw
# 4305578  yiUKLTuD209a3Vvsi5VcUQ  TKpEGZZAUc5GXuYkw1SNSw
# 4305579  zBbtEF7GGmiZQQxaL3ufYg  edf8Xw-tBzLIc9C400H7rw
#
#                     business_id  \
# 0        0AzLzHfOJgL7ROwhdww2ew
# 1        0AzLzHfOJgL7ROwhdww2ew
# 2        0AzLzHfOJgL7ROwhdww2ew
# 3        0AzLzHfOJgL7ROwhdww2ew
# 4        0AzLzHfOJgL7ROwhdww2ew
# ...                         ...
# 4305575  BgEaIonKZO1pG6_rxqcy0w
# 4305576  BgEaIonKZO1pG6_rxqcy0w
# 4305577  BgEaIonKZO1pG6_rxqcy0w
# 4305578  BgEaIonKZO1pG6_rxqcy0w
# 4305579  BgEaIonKZO1pG6_rxqcy0w
#
#                                                       text  useful  stars  \
# 0        I've stayed at many Marriott and Renaissance M...       1      2
# 1        I was a there for a professional conference. s...       0      4
# 2        What a nice place for our corporate conference...       1      5
# 3        A cavernous and well appointed branch which is...       0      4
# 4        Food and service is A-ok.   Server was nice bu...       0      3
# ...                                                    ...     ...    ...
# 4305575  Hired them for my baby shower last weekend, an...       2      5
# 4305576  Hands down the best food ever. If you need a r...       1      5
# 4305577  I was a little worried when I hired them for a...       2      5
# 4305578  The food was great, not heavy and the differen...       0      5
# 4305579  Very great job on my daughters graduation part...       1      5
#
#          funny  cool                date  user_review_count  ...  \
# 0            1     1 2010-01-08 02:29:15                 67  ...
# 1            0     0 2011-09-26 00:30:39                 11  ...
# 2            1     1 2019-03-02 15:54:35                303  ...
# 3            0     0 2011-06-14 16:40:58                459  ...
# 4            0     0 2017-08-26 00:45:54                279  ...
# ...        ...   ...                 ...                ...  ...
# 4305575      0     0 2016-07-03 03:23:08                 15  ...
# 4305576      0     1 2014-11-06 16:38:59                  4  ...
# 4305577      0     0 2011-08-15 22:43:09                 10  ...
# 4305578      0     0 2011-04-20 13:53:53                  5  ...
# 4305579      0     0 2017-07-21 12:26:40                 40  ...
#
#          user_average_stars  friend_count                             name  \
# 0                      3.72             1  Renaissance Orlando at SeaWorld
# 1                      4.25           382  Renaissance Orlando at SeaWorld
# 2                      4.36           139  Renaissance Orlando at SeaWorld
# 3                      3.58           389  Renaissance Orlando at SeaWorld
# 4                      3.89            22  Renaissance Orlando at SeaWorld
# ...                     ...           ...                              ...
# 4305575                3.94             1         Mendoza & Son's Catering
# 4305576                5.00             1         Mendoza & Son's Catering
# 4305577                4.09             1         Mendoza & Son's Catering
# 4305578                1.80             1         Mendoza & Son's Catering
# 4305579                2.76           126         Mendoza & Son's Catering
#
#           latitude   longitude       city  state restaurant_stars  \
# 0        28.411733  -81.468472    Orlando     FL              3.5
# 1        28.411733  -81.468472    Orlando     FL              3.5
# 2        28.411733  -81.468472    Orlando     FL              3.5
# 3        28.411733  -81.468472    Orlando     FL              3.5
# 4        28.411733  -81.468472    Orlando     FL              3.5
# ...            ...         ...        ...    ...              ...
# 4305575  45.606316 -122.513093  Vancouver     WA              5.0
# 4305576  45.606316 -122.513093  Vancouver     WA              5.0
# 4305577  45.606316 -122.513093  Vancouver     WA              5.0
# 4305578  45.606316 -122.513093  Vancouver     WA              5.0
# 4305579  45.606316 -122.513093  Vancouver     WA              5.0
#
#                                                 categories  \
# 0        Hotels, Hotels & Travel, Restaurants, Event Pl...
# 1        Hotels, Hotels & Travel, Restaurants, Event Pl...
# 2        Hotels, Hotels & Travel, Restaurants, Event Pl...
# 3        Hotels, Hotels & Travel, Restaurants, Event Pl...
# 4        Hotels, Hotels & Travel, Restaurants, Event Pl...
# ...                                                    ...
# 4305575  Event Planning & Services, Caterers, Food Stan...
# 4305576  Event Planning & Services, Caterers, Food Stan...
# 4305577  Event Planning & Services, Caterers, Food Stan...
# 4305578  Event Planning & Services, Caterers, Food Stan...
# 4305579  Event Planning & Services, Caterers, Food Stan...
#
#          restaurant_review_count
# 0                            290
# 1                            290
# 2                            290
# 3                            290
# 4                            290
# ...                          ...
# 4305575                        8
# 4305576                        8
# 4305577                        8
# 4305578                        8
# 4305579                        8
#
# [4305580 rows x 25 columns]

# %%
yelp.to_csv('yelp_restaurant_review.csv',index=False)
